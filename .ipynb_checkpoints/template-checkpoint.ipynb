# %% [markdown]
# # Open Space Toolkit Template
#
# This is a template notebook for working with Open Space Toolkit (OSTk).
#
# ## Getting Started
#
# You can import OSTk libraries and start working with space engineering applications.

# %%
# Import your OSTk libraries here
# Example:
# from ostk.physics import Environment
# from ostk.astrodynamics import Orbit

# %%
# Your code here
